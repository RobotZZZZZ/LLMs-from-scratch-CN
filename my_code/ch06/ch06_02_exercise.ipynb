# %%
# 使用sys.path添加上级目录
import sys
import os
package_path = os.path.dirname(os.path.dirname(os.getcwd()))
file_path = os.path.join(package_path, "ch06", "01_main-chapter-code")
print(file_path)
sys.path.append(file_path)

import torch
if torch.cuda.is_available():
   device = torch.device("cuda")
elif torch.backends.mps.is_available():
   device = torch.device("mps")
else:
   device = torch.device("cpu")
# Out:
# F:\project\LLMs-from-scratch-CN\ch06\01_main-chapter-code

# %% [markdown]
# # EXERCISE 6.1 INCREASING THE CONTEXT LENGTH
# Pad the inputs to the maximum number of tokens the model supports and observe
# how it impacts the predictive performance.

# %%
max_length = 1024

# %%
import tiktoken

tokenizer = tiktoken.get_encoding("gpt2")
print(tokenizer.encode("<|endoftext|>", allowed_special={"<|endoftext|>"}))
# Out:
# [50256]

# %%
import torch
from torch.utils.data import Dataset
import pandas as pd

class SpamDataset(Dataset):
    def __init__(self, csv_file, tokenizer, max_length=None, pad_token_id=50256):
        self.data = pd.read_csv(csv_file)
        # 编码输入数据
        self.encoded_texts = [
            tokenizer.encode(text) for text in self.data["Text"]
        ]
        # 最大长度截断
        if max_length is None:
            self.max_length = self._longest_encoded_length()
        else:
            self.max_length = max_length
            self.encode_texts = [
                encoded_text[:self.max_length]
                for encoded_text in self.encoded_texts
            ]
        # 填充
        self.encoded_texts = [
            encoded_text + [pad_token_id] * (self.max_length - len(encoded_text))
            for encoded_text in self.encoded_texts
        ]

    def __getitem__(self, index):
        encoded = self.encoded_texts[index]
        label = self.data.iloc[index]["Label"]
        return (
            torch.tensor(encoded, dtype=torch.long),
            torch.tensor(label, dtype=torch.long)
        )
    
    def __len__(self):
        return len(self.data)
    
    def _longest_encoded_length(self):
        max_length = 0
        for encoded_text in self.encoded_texts:
            encoded_length = len(encoded_text)
            if encoded_length > max_length:
                max_length = encoded_length
        return max_length

# %%
train_dataset = SpamDataset(
    csv_file="train.csv",
    max_length=max_length,
    tokenizer=tokenizer
)

val_dataset = SpamDataset(
    csv_file="validation.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)
test_dataset = SpamDataset(
    csv_file="test.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)

print(train_dataset.max_length)
# Out:
# 1024

# %%
from torch.utils.data import DataLoader

num_workers = 0
batch_size = 8

torch.manual_seed(123)

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    drop_last=True,
)
val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)

# %%
print("Train loader:")
for input_batch, target_batch in train_loader:
    pass

print("Input batch dimensions:", input_batch.shape)
print("Label batch dimensions", target_batch.shape)
# Out:
# Train loader:
# Input batch dimensions: torch.Size([8, 1024])
# Label batch dimensions torch.Size([8])

# %%
CHOOSE_MODEL = "gpt2-small (124M)"
INPUT_PROMPT = "Every effort moves"

BASE_CONFIG = {
    "vocab_size": 50257,     # 词表大小
    "context_length": 1024,  # 上下文长度
    "drop_rate": 0.0,        # Dropout率
    "qkv_bias": True         # qkv向量是否使用Bias
}

model_configs = {
    "gpt2-small (124M)": {"emb_dim": 768, "n_layers": 12, "n_heads": 12},
    "gpt2-medium (355M)": {"emb_dim": 1024, "n_layers": 24, "n_heads": 16},
    "gpt2-large (774M)": {"emb_dim": 1280, "n_layers": 36, "n_heads": 20},
    "gpt2-xl (1558M)": {"emb_dim": 1600, "n_layers": 48, "n_heads": 25},
}

BASE_CONFIG.update(model_configs[CHOOSE_MODEL])

# 上下文长度应小于max_length
assert train_dataset.max_length <= BASE_CONFIG["context_length"], (
    f"Dataset length {train_dataset.max_length} exceeds model's context "
    f"length {BASE_CONFIG['context_length']}. Reinitialize data sets with "
    f"`max_length={BASE_CONFIG['context_length']}`"
)

# %%
from gpt_download import download_and_load_gpt2
from previous_chapters import GPTModel, load_weights_into_gpt

# 下载预训练模型权重
model_size = CHOOSE_MODEL.split(" ")[-1].lstrip("(").rstrip(")")
settings, params = download_and_load_gpt2(model_size=model_size, models_dir="gpt2")
model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.eval()
# Out:
# File already exists and is up-to-date: gpt2\124M\checkpoint
# File already exists and is up-to-date: gpt2\124M\encoder.json
# File already exists and is up-to-date: gpt2\124M\hparams.json
# File already exists and is up-to-date: gpt2\124M\model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2\124M\model.ckpt.index
# File already exists and is up-to-date: gpt2\124M\model.ckpt.meta
# File already exists and is up-to-date: gpt2\124M\vocab.bpe
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNorm()
#   (out_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# 冻结参数
for param in model.parameters():
    param.requires_grad = False

# %%
# 替换输出层，用于分类
torch.manual_seed(123)

num_classes = 2
model.out_head = torch.nn.Linear(in_features=BASE_CONFIG["emb_dim"], out_features=num_classes)

# %%
# 除了输出层外，令trf的最后一个模块和final_norm的参数可训练
for param in model.trf_blocks[-1].parameters():
    param.requires_grad = True

for param in model.final_norm.parameters():
    param.requires_grad = True

# %%
# 计算分类准备率
def calc_accuracy_loader(data_loader, model, device, num_batches=None):
    model.eval()
    correct_predictions, num_examples = 0, 0
    if num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))
    
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            # 将数据移到指定设备
            input_batch, target_batch = input_batch.to(device), target_batch.to(device)
            # 模型预估
            with torch.no_grad():
                logits = model(input_batch)[:, -1, :]
            # 获取分类结果
            predicted_labels = torch.argmax(logits, dim=-1)
            # 统计总样本量、分类正确样本量
            num_examples += predicted_labels.shape[0]
            correct_predictions += (predicted_labels == target_batch).sum().item()
        else:
            break
    return correct_predictions / num_examples

# %%
# 定义batch训练损失
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    # 只关注最后一个输出
    logits = model(input_batch)[:, -1, :]
    # 交叉熵损失
    loss = torch.nn.functional.cross_entropy(logits, target_batch)
    return loss

# %%
# 定义loader训练损失
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        for i, (input_batch, target_batch) in enumerate(data_loader):
            if i < num_batches:
                loss = calc_loss_batch(input_batch, target_batch, model, device)
                total_loss += loss.item()
            else:
                break
    return total_loss / num_batches

# %%
# 定义训练过程
def train_classifier_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                            eval_freq, eval_iter):
    train_losses, val_losses, train_accs, val_accs = [], [], [], []
    examples_seen, global_step = 0, -1
    for epoch in range(num_epochs):
        model.train()
        for input_batch, target_batch in train_loader:
            # 初始化梯度
            optimizer.zero_grad()
            # loss计算
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            # 反向传播
            loss.backward()
            # 权重更新
            optimizer.step()
            
            examples_seen += input_batch.shape[0]
            global_step += 1

            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter
                )
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                print(f"Ep {epoch+1} (Step {global_step:06d}) "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")
        
        train_accuracy = calc_accuracy_loader(train_loader, model, device, num_batches=eval_iter)
        val_accuracy = calc_accuracy_loader(val_loader, model, device, num_batches=eval_iter)
        print(f"Training accuracy: {train_accuracy * 100:.2f}% | ", end="")
        print(f"Validation accuracy: {val_accuracy * 100:.2f}%")
        train_accs.append(train_accuracy)
        val_accs.append(val_accuracy)

    return train_losses, val_losses, train_accs, val_accs, examples_seen

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
model.to(device)
# Out:
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNorm()
#   (out_head): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# 训练模型
import time 

start_time = time.time()

torch.manual_seed(123)

optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.1)

num_epochs = 5
train_losses, val_losses, train_accs, val_accs, examples_seen = train_classifier_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=50, eval_iter=5,
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")

# %%
train_accuracy = calc_accuracy_loader(train_loader, model, device)
val_accuracy = calc_accuracy_loader(val_loader, model, device)
test_accuracy = calc_accuracy_loader(test_loader, model, device)

print(f"Training accuracy: {train_accuracy*100:.2f}%")
print(f"Validation accuracy: {val_accuracy*100:.2f}%")
print(f"Test accuracy: {test_accuracy*100:.2f}%")
# Out:
# Training accuracy: 83.85%
# Validation accuracy: 82.55%
# Test accuracy: 84.33%

# %%
# 上下文长度变化：120 --> 1024
# 训练时间：0.74 mins --> 9.94 mins 
# 准确率变化：(79.33%, 74.50%, 80.67%) --> (83.85%, 82.55%, 84.33%)

# %%
! cd ..\..\ch06\02_bonus_additional-experiments && python additional_experiments.py --context_length "model_context_length"
# Out:
# File downloaded and saved as sms_spam_collection\SMSSpamCollection.tsv
# Ep 1 (Step 000000): Train loss 4.888, Val loss 4.461
# Ep 1 (Step 000050): Train loss 0.690, Val loss 0.687
# Ep 1 (Step 000100): Train loss 0.528, Val loss 0.550
# Training accuracy: 82.50% | Validation accuracy: 92.50%
# Ep 2 (Step 000150): Train loss 0.479, Val loss 0.386
# Ep 2 (Step 000200): Train loss 0.517, Val loss 0.355
# Ep 2 (Step 000250): Train loss 0.288, Val loss 0.308
# Training accuracy: 77.50% | Validation accuracy: 85.00%
# Ep 3 (Step 000300): Train loss 0.502, Val loss 0.287
# Ep 3 (Step 000350): Train loss 0.314, Val loss 0.280
# Training accuracy: 70.00% | Validation accuracy: 87.50%
# Ep 4 (Step 000400): Train loss 0.496, Val loss 0.307
# Ep 4 (Step 000450): Train loss 0.464, Val loss 0.274
# Ep 4 (Step 000500): Train loss 0.566, Val loss 0.275
# Training accuracy: 85.00% | Validation accuracy: 85.00%
# Ep 5 (Step 000550): Train loss 0.354, Val loss 0.260
# Ep 5 (Step 000600): Train loss 0.484, Val loss 0.299
# Training accuracy: 87.50% | Validation accuracy: 87.50%
# Training completed in 15.86 minutes.
# Training accuracy: 83.08%
# Validation accuracy: 87.92%
# Test accuracy: 78.33%
# 2025-04-27 20:42:17.819843: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 20:42:18.724641: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#
# checkpoint:   0%|          | 0.00/77.0 [00:00<?, ?iB/s]
# checkpoint: 100%|██████████| 77.0/77.0 [00:00<00:00, 38.5kiB/s]
#
# encoder.json:   0%|          | 0.00/1.04M [00:00<?, ?iB/s]
# encoder.json:   3%|▎         | 32.8k/1.04M [00:00<00:04, 213kiB/s]
# encoder.json:   9%|▉         | 98.3k/1.04M [00:00<00:02, 335kiB/s]
# encoder.json:  20%|██        | 213k/1.04M [00:00<00:01, 521kiB/s]
# encoder.json:  46%|████▌     | 475k/1.04M [00:00<00:00, 982kiB/s]
# encoder.json:  71%|███████   | 737k/1.04M [00:00<00:00, 1.24MiB/s]
# encoder.json: 100%|██████████| 1.04M/1.04M [00:00<00:00, 1.27MiB/s]
#
# hparams.json:   0%|          | 0.00/90.0 [00:00<?, ?iB/s]
# hparams.json: 100%|██████████| 90.0/90.0 [00:00<00:00, 44.8kiB/s]
#
# model.ckpt.data-00000-of-00001:   0%|          | 0.00/498M [00:00<?, ?iB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 16.4k/498M [00:00<1:18:14, 106kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 81.9k/498M [00:00<28:20, 293kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 197k/498M [00:00<16:41, 497kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 426k/498M [00:00<09:20, 887kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 705k/498M [00:00<06:48, 1.22MiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 1.21M/498M [00:00<04:18, 1.92MiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 1.44M/498M [00:01<04:22, 1.89MiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 1.63M/498M [00:01<05:49, 1.42MiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 1.79M/498M [00:01<08:39, 955kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 1.91M/498M [00:01<10:46, 767kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.00M/498M [00:02<12:56, 638kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.08M/498M [00:02<14:51, 556kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.15M/498M [00:02<15:46, 524kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.20M/498M [00:02<17:44, 466kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.25M/498M [00:02<19:04, 433kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.30M/498M [00:03<21:56, 376kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.34M/498M [00:03<21:44, 380kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.39M/498M [00:03<21:02, 392kiB/s]
# model.ckpt.data-00000-of-00001:   0%|          | 2.44M/498M [00:03<22:06, 373kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.49M/498M [00:03<21:14, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.54M/498M [00:03<20:31, 402kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.58M/498M [00:03<21:34, 383kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.62M/498M [00:03<22:00, 375kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.67M/498M [00:04<22:58, 359kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.72M/498M [00:04<22:20, 369kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.76M/498M [00:04<24:10, 341kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.80M/498M [00:04<23:06, 357kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.85M/498M [00:04<22:06, 373kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.89M/498M [00:04<22:41, 363kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.93M/498M [00:04<22:47, 362kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 2.98M/498M [00:04<24:16, 340kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.03M/498M [00:05<23:54, 345kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.07M/498M [00:05<23:58, 344kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.10M/498M [00:05<25:17, 326kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.15M/498M [00:05<23:45, 347kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.19M/498M [00:05<24:54, 331kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.23M/498M [00:05<26:13, 314kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.28M/498M [00:05<23:52, 345kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.31M/498M [00:05<24:37, 335kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.36M/498M [00:06<23:11, 355kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.41M/498M [00:06<22:22, 368kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.46M/498M [00:06<21:17, 387kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.50M/498M [00:06<21:09, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.56M/498M [00:06<19:46, 417kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.60M/498M [00:06<20:05, 410kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.67M/498M [00:06<19:37, 420kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.74M/498M [00:06<17:45, 464kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.78M/498M [00:07<18:01, 457kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.85M/498M [00:07<17:10, 480kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.90M/498M [00:07<17:39, 466kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 3.95M/498M [00:07<17:57, 458kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.01M/498M [00:07<16:54, 487kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.08M/498M [00:07<15:41, 524kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.15M/498M [00:07<15:11, 541kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.21M/498M [00:07<14:57, 550kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.28M/498M [00:07<15:11, 541kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.34M/498M [00:08<14:52, 553kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.40M/498M [00:08<15:21, 535kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.45M/498M [00:08<17:54, 459kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.50M/498M [00:08<19:51, 414kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.54M/498M [00:08<21:28, 383kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.59M/498M [00:08<22:28, 366kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.64M/498M [00:08<22:06, 372kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.69M/498M [00:09<21:46, 378kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.74M/498M [00:09<22:38, 363kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.79M/498M [00:09<20:58, 392kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.83M/498M [00:09<21:24, 384kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.87M/498M [00:09<21:44, 378kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.92M/498M [00:09<21:28, 382kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 4.97M/498M [00:09<21:55, 375kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.01M/498M [00:09<20:56, 392kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.08M/498M [00:09<18:58, 433kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.13M/498M [00:10<18:20, 448kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.21M/498M [00:10<17:30, 469kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.26M/498M [00:10<17:20, 473kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.31M/498M [00:10<18:39, 440kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.36M/498M [00:10<18:39, 440kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.41M/498M [00:10<19:29, 421kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.47M/498M [00:10<18:32, 443kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.54M/498M [00:10<17:00, 483kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.60M/498M [00:11<16:05, 510kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.69M/498M [00:11<14:54, 550kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.77M/498M [00:11<13:39, 601kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.85M/498M [00:11<12:52, 637kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.93M/498M [00:11<14:16, 574kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 5.99M/498M [00:11<14:35, 561kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 6.05M/498M [00:11<16:21, 501kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 6.10M/498M [00:12<20:06, 408kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 6.15M/498M [00:12<20:17, 404kiB/s]
# model.ckpt.data-00000-of-00001:   1%|          | 6.19M/498M [00:12<20:38, 397kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.23M/498M [00:12<22:47, 359kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.28M/498M [00:12<22:01, 372kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.33M/498M [00:12<22:52, 358kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.37M/498M [00:12<23:35, 347kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.42M/498M [00:12<22:07, 370kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.47M/498M [00:13<21:04, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.51M/498M [00:13<23:39, 346kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.55M/498M [00:13<23:06, 354kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.60M/498M [00:13<21:41, 377kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.65M/498M [00:13<20:47, 394kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.70M/498M [00:13<20:09, 406kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.75M/498M [00:13<19:42, 415kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.82M/498M [00:13<19:51, 412kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.87M/498M [00:14<21:17, 384kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.92M/498M [00:14<21:01, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 6.96M/498M [00:14<21:41, 377kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.01M/498M [00:14<21:15, 385kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.06M/498M [00:14<21:04, 388kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.11M/498M [00:14<21:09, 387kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.16M/498M [00:14<21:00, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.21M/498M [00:15<22:09, 369kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.26M/498M [00:15<22:39, 361kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.31M/498M [00:15<21:27, 381kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.36M/498M [00:15<21:00, 389kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.40M/498M [00:15<21:09, 386kiB/s]
# model.ckpt.data-00000-of-00001:   1%|▏         | 7.44M/498M [00:15<21:48, 375kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.47M/498M [00:15<25:49, 316kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.52M/498M [00:15<24:48, 329kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.57M/498M [00:16<23:53, 342kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.62M/498M [00:16<22:12, 368kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.67M/498M [00:16<23:58, 341kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.72M/498M [00:16<22:21, 365kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.76M/498M [00:16<22:53, 357kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.80M/498M [00:16<25:26, 321kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.85M/498M [00:16<23:17, 350kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.90M/498M [00:16<21:51, 374kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.94M/498M [00:17<22:19, 366kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 7.97M/498M [00:17<22:49, 358kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.01M/498M [00:17<23:09, 352kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.05M/498M [00:17<24:32, 333kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.09M/498M [00:17<23:01, 354kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.14M/498M [00:17<24:19, 335kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.19M/498M [00:17<22:25, 364kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.24M/498M [00:17<22:03, 370kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.29M/498M [00:18<21:36, 377kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.34M/498M [00:18<20:39, 395kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.39M/498M [00:18<20:19, 401kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.44M/498M [00:18<19:47, 412kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.50M/498M [00:18<17:39, 462kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.59M/498M [00:18<15:05, 540kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.65M/498M [00:18<16:15, 502kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.72M/498M [00:18<15:40, 520kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.78M/498M [00:19<15:10, 537kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.85M/498M [00:19<14:45, 552kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 8.91M/498M [00:19<14:27, 563kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.00M/498M [00:19<13:36, 599kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.08M/498M [00:19<12:31, 651kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.16M/498M [00:19<12:25, 656kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.23M/498M [00:19<14:58, 543kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.28M/498M [00:19<17:10, 474kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.34M/498M [00:20<17:46, 458kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.38M/498M [00:20<19:40, 414kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.43M/498M [00:20<22:18, 365kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.47M/498M [00:20<21:52, 372kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.52M/498M [00:20<20:54, 389kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.56M/498M [00:20<20:41, 393kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.60M/498M [00:20<21:44, 374kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.65M/498M [00:20<20:45, 392kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.69M/498M [00:21<20:43, 393kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.73M/498M [00:21<21:34, 377kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.78M/498M [00:21<20:39, 394kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.83M/498M [00:21<19:59, 407kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.88M/498M [00:21<19:37, 414kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.93M/498M [00:21<19:50, 410kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 9.97M/498M [00:21<20:19, 400kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.0M/498M [00:21<21:26, 379kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.1M/498M [00:21<21:24, 380kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.1M/498M [00:22<22:08, 367kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.1M/498M [00:22<26:07, 311kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.2M/498M [00:22<22:13, 366kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.2M/498M [00:22<23:05, 352kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.3M/498M [00:22<22:35, 360kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.3M/498M [00:22<22:34, 360kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.4M/498M [00:22<22:24, 363kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.4M/498M [00:22<22:38, 359kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.5M/498M [00:23<19:45, 411kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.5M/498M [00:23<21:17, 381kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.6M/498M [00:23<19:49, 410kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.6M/498M [00:23<19:30, 416kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.7M/498M [00:23<18:28, 439kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.7M/498M [00:23<18:52, 430kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.8M/498M [00:23<19:30, 416kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.8M/498M [00:23<19:56, 407kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.9M/498M [00:24<20:40, 393kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 10.9M/498M [00:24<20:31, 395kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.0M/498M [00:24<19:54, 407kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.0M/498M [00:24<19:28, 416kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.1M/498M [00:24<19:10, 423kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.1M/498M [00:24<19:28, 417kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.2M/498M [00:24<19:10, 423kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.2M/498M [00:24<22:20, 363kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.3M/498M [00:25<21:08, 383kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.3M/498M [00:25<20:49, 389kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.4M/498M [00:25<21:33, 376kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.4M/498M [00:25<21:10, 383kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.5M/498M [00:25<20:22, 398kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.5M/498M [00:25<20:26, 397kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.5M/498M [00:25<20:54, 388kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.6M/498M [00:25<18:35, 436kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.7M/498M [00:25<16:56, 478kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.7M/498M [00:26<15:53, 509kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.8M/498M [00:26<14:54, 543kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.9M/498M [00:26<13:48, 586kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 11.9M/498M [00:26<14:15, 568kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.0M/498M [00:26<15:07, 535kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.1M/498M [00:26<17:06, 473kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.1M/498M [00:26<17:59, 450kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.1M/498M [00:26<19:36, 413kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.2M/498M [00:27<20:18, 398kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.2M/498M [00:27<19:45, 409kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.3M/498M [00:27<17:40, 458kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.4M/498M [00:27<18:12, 444kiB/s]
# model.ckpt.data-00000-of-00001:   2%|▏         | 12.4M/498M [00:27<16:46, 482kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.5M/498M [00:27<17:16, 468kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.5M/498M [00:27<17:41, 457kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.6M/498M [00:27<18:13, 444kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.6M/498M [00:28<21:20, 379kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.7M/498M [00:28<21:43, 372kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.7M/498M [00:28<23:35, 343kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.7M/498M [00:28<23:49, 339kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.8M/498M [00:28<23:35, 343kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.8M/498M [00:28<25:56, 312kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.9M/498M [00:28<23:21, 346kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 12.9M/498M [00:28<21:59, 367kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.0M/498M [00:29<20:55, 386kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.0M/498M [00:29<21:10, 382kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.1M/498M [00:29<19:21, 417kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.1M/498M [00:29<18:55, 427kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.2M/498M [00:29<19:20, 418kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.2M/498M [00:29<18:31, 436kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.3M/498M [00:29<19:34, 412kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.3M/498M [00:29<19:15, 419kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.4M/498M [00:30<21:06, 382kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.4M/498M [00:30<21:32, 375kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.5M/498M [00:30<22:39, 356kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.5M/498M [00:30<24:23, 331kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.5M/498M [00:30<25:00, 323kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.6M/498M [00:30<23:38, 341kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.6M/498M [00:30<23:42, 340kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.6M/498M [00:30<25:01, 322kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.7M/498M [00:31<25:02, 322kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.7M/498M [00:31<23:55, 337kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.8M/498M [00:31<22:06, 365kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.8M/498M [00:31<21:57, 367kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.9M/498M [00:31<21:33, 374kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 13.9M/498M [00:31<18:52, 427kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.0M/498M [00:31<17:16, 467kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.1M/498M [00:31<15:56, 506kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.1M/498M [00:31<15:03, 535kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.2M/498M [00:32<14:52, 542kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.3M/498M [00:32<15:25, 522kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.3M/498M [00:32<15:14, 529kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.4M/498M [00:32<13:42, 587kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.5M/498M [00:32<15:08, 532kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.5M/498M [00:32<16:07, 499kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.6M/498M [00:32<16:30, 488kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.6M/498M [00:32<16:54, 476kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.7M/498M [00:33<17:24, 463kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.7M/498M [00:33<19:36, 411kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.8M/498M [00:33<19:16, 417kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.8M/498M [00:33<19:29, 413kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.9M/498M [00:33<19:27, 414kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 14.9M/498M [00:33<18:21, 438kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.0M/498M [00:33<18:20, 439kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.0M/498M [00:33<16:41, 482kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.1M/498M [00:34<17:15, 466kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.1M/498M [00:34<17:33, 458kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.2M/498M [00:34<17:50, 451kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.3M/498M [00:34<18:26, 436kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.3M/498M [00:34<18:27, 436kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.4M/498M [00:34<18:23, 437kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.4M/498M [00:34<16:49, 478kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.5M/498M [00:34<17:19, 464kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.5M/498M [00:34<17:28, 460kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.6M/498M [00:35<17:46, 452kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.6M/498M [00:35<16:19, 492kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.7M/498M [00:35<17:21, 463kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.7M/498M [00:35<19:29, 412kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.8M/498M [00:35<19:09, 419kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.8M/498M [00:35<20:51, 385kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.9M/498M [00:35<21:00, 382kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 15.9M/498M [00:35<19:43, 407kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.0M/498M [00:36<20:12, 397kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.0M/498M [00:36<24:05, 333kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.1M/498M [00:36<22:24, 358kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.1M/498M [00:36<23:17, 345kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.1M/498M [00:36<22:02, 364kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.2M/498M [00:36<20:49, 385kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.2M/498M [00:36<21:16, 377kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.3M/498M [00:36<21:59, 365kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.3M/498M [00:37<22:30, 356kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.3M/498M [00:37<23:01, 349kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.4M/498M [00:37<25:13, 318kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.4M/498M [00:37<24:54, 322kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.5M/498M [00:37<23:55, 335kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.5M/498M [00:37<22:05, 363kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.6M/498M [00:37<25:48, 311kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.6M/498M [00:37<24:14, 331kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.7M/498M [00:38<22:16, 360kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.7M/498M [00:38<22:10, 362kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.7M/498M [00:38<22:08, 362kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.8M/498M [00:38<24:01, 334kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.8M/498M [00:38<24:34, 326kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.9M/498M [00:38<23:30, 341kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 16.9M/498M [00:38<23:42, 338kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.0M/498M [00:38<21:39, 370kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.0M/498M [00:39<22:32, 356kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.1M/498M [00:39<21:13, 378kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.1M/498M [00:39<20:27, 392kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.2M/498M [00:39<19:41, 407kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.2M/498M [00:39<19:15, 416kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.3M/498M [00:39<17:16, 463kiB/s]
# model.ckpt.data-00000-of-00001:   3%|▎         | 17.4M/498M [00:39<16:03, 499kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.4M/498M [00:39<14:07, 567kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.5M/498M [00:40<14:00, 571kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.6M/498M [00:40<16:43, 479kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.6M/498M [00:40<17:41, 452kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.7M/498M [00:40<17:25, 459kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.7M/498M [00:40<17:47, 450kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.8M/498M [00:40<18:23, 435kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.8M/498M [00:40<20:44, 386kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.9M/498M [00:40<21:35, 371kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 17.9M/498M [00:41<21:59, 364kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.0M/498M [00:41<21:52, 366kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.0M/498M [00:41<20:47, 385kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.1M/498M [00:41<20:02, 399kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.1M/498M [00:41<19:28, 411kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.2M/498M [00:41<17:22, 460kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.2M/498M [00:41<18:09, 440kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.3M/498M [00:41<17:41, 452kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.3M/498M [00:42<17:51, 448kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.4M/498M [00:42<17:20, 461kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.4M/498M [00:42<17:35, 454kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.5M/498M [00:42<17:47, 449kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.5M/498M [00:42<17:55, 446kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.6M/498M [00:42<17:32, 455kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▎         | 18.6M/498M [00:42<16:35, 481kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 18.7M/498M [00:42<15:35, 512kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 18.8M/498M [00:43<15:13, 524kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 18.9M/498M [00:43<15:12, 525kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 18.9M/498M [00:43<14:44, 541kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.0M/498M [00:43<14:28, 552kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.1M/498M [00:43<15:58, 499kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.1M/498M [00:43<17:48, 448kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.2M/498M [00:43<18:33, 430kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.2M/498M [00:43<19:03, 418kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.2M/498M [00:44<20:02, 398kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.3M/498M [00:44<20:33, 388kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.3M/498M [00:44<21:45, 366kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.4M/498M [00:44<21:12, 376kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.4M/498M [00:44<21:42, 367kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.4M/498M [00:44<23:55, 333kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.5M/498M [00:44<21:21, 373kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.6M/498M [00:44<22:15, 358kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.6M/498M [00:45<21:04, 378kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.7M/498M [00:45<21:20, 373kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.7M/498M [00:45<21:24, 372kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.7M/498M [00:45<20:21, 391kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.8M/498M [00:45<22:44, 350kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.8M/498M [00:45<21:52, 364kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.9M/498M [00:45<23:09, 344kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 19.9M/498M [00:45<23:28, 339kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.0M/498M [00:46<21:54, 363kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.0M/498M [00:46<23:07, 344kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.1M/498M [00:46<22:59, 346kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.1M/498M [00:46<22:20, 356kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.2M/498M [00:46<22:20, 356kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.2M/498M [00:46<22:03, 361kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.3M/498M [00:46<20:47, 383kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.3M/498M [00:46<20:31, 388kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.3M/498M [00:47<20:41, 385kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.4M/498M [00:47<20:54, 381kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.4M/498M [00:47<21:25, 371kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.5M/498M [00:47<22:01, 361kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.5M/498M [00:47<24:36, 323kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.6M/498M [00:47<22:25, 355kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.6M/498M [00:47<23:03, 345kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.6M/498M [00:47<22:36, 352kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.7M/498M [00:48<22:32, 353kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.7M/498M [00:48<21:45, 365kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.8M/498M [00:48<20:37, 385kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.8M/498M [00:48<21:11, 375kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.9M/498M [00:48<21:04, 377kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 20.9M/498M [00:48<20:08, 395kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.0M/498M [00:48<19:46, 402kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.0M/498M [00:48<19:20, 411kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.1M/498M [00:48<17:11, 462kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.2M/498M [00:49<16:02, 495kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.2M/498M [00:49<14:03, 565kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.3M/498M [00:49<12:54, 615kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.4M/498M [00:49<12:35, 630kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.5M/498M [00:49<11:01, 720kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.6M/498M [00:49<10:19, 769kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.7M/498M [00:49<09:22, 846kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.8M/498M [00:49<10:24, 762kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 21.9M/498M [00:50<10:39, 744kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.0M/498M [00:50<12:59, 610kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.0M/498M [00:50<15:19, 517kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.1M/498M [00:50<16:40, 475kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.1M/498M [00:50<17:44, 447kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.2M/498M [00:50<18:30, 428kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.2M/498M [00:50<20:29, 387kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.3M/498M [00:51<20:59, 377kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.3M/498M [00:51<20:29, 387kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.4M/498M [00:51<20:51, 380kiB/s]
# model.ckpt.data-00000-of-00001:   4%|▍         | 22.4M/498M [00:51<21:03, 376kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.4M/498M [00:51<20:03, 395kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.5M/498M [00:51<17:35, 450kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.6M/498M [00:51<18:19, 432kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.6M/498M [00:51<18:47, 421kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.6M/498M [00:52<21:13, 373kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.7M/498M [00:52<20:57, 378kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.7M/498M [00:52<20:02, 395kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.8M/498M [00:52<20:35, 385kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.8M/498M [00:52<21:49, 363kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.9M/498M [00:52<22:25, 353kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.9M/498M [00:52<26:40, 297kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 22.9M/498M [00:52<24:35, 322kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.0M/498M [00:53<22:37, 350kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.0M/498M [00:53<22:46, 347kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.1M/498M [00:53<21:47, 363kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.1M/498M [00:53<20:00, 395kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.2M/498M [00:53<19:46, 400kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.2M/498M [00:53<19:08, 413kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.3M/498M [00:53<19:05, 414kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.3M/498M [00:53<20:22, 388kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.4M/498M [00:54<21:26, 369kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.4M/498M [00:54<21:03, 375kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.5M/498M [00:54<21:00, 376kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.5M/498M [00:54<20:44, 381kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.6M/498M [00:54<21:49, 362kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.6M/498M [00:54<21:07, 374kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.7M/498M [00:54<20:11, 391kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.7M/498M [00:54<19:32, 404kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.8M/498M [00:55<17:29, 451kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.9M/498M [00:55<17:43, 445kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 23.9M/498M [00:55<16:19, 484kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.0M/498M [00:55<16:45, 471kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.0M/498M [00:55<17:37, 448kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.1M/498M [00:55<17:13, 458kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.2M/498M [00:55<17:25, 453kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.2M/498M [00:55<16:43, 472kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.3M/498M [00:56<19:34, 403kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.3M/498M [00:56<19:12, 411kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.4M/498M [00:56<19:57, 395kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.4M/498M [00:56<22:16, 354kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.5M/498M [00:56<20:33, 384kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.5M/498M [00:56<21:21, 369kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.5M/498M [00:56<21:24, 368kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.6M/498M [00:57<21:05, 374kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.6M/498M [00:57<21:18, 370kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.7M/498M [00:57<20:16, 389kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.7M/498M [00:57<21:20, 369kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.8M/498M [00:57<21:18, 370kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.8M/498M [00:57<22:24, 352kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▍         | 24.9M/498M [00:57<22:43, 347kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 24.9M/498M [00:57<21:25, 368kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.0M/498M [00:58<23:49, 331kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.0M/498M [00:58<22:41, 347kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.0M/498M [00:58<23:24, 337kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.1M/498M [00:58<22:27, 351kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.1M/498M [00:58<22:27, 351kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.2M/498M [00:58<23:49, 331kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.2M/498M [00:58<25:08, 313kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.2M/498M [00:58<22:41, 347kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.3M/498M [00:59<22:18, 353kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.3M/498M [00:59<21:43, 363kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.4M/498M [00:59<21:38, 364kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.4M/498M [00:59<22:19, 353kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.5M/498M [00:59<22:17, 353kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.5M/498M [00:59<24:06, 326kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.6M/498M [00:59<21:58, 358kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.6M/498M [00:59<21:51, 360kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.6M/498M [01:00<23:15, 338kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.7M/498M [01:00<22:04, 356kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.7M/498M [01:00<22:43, 346kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.8M/498M [01:00<21:10, 371kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.8M/498M [01:00<22:09, 355kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.9M/498M [01:00<22:34, 348kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 25.9M/498M [01:00<23:43, 331kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.0M/498M [01:00<22:52, 344kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.0M/498M [01:01<25:46, 305kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.0M/498M [01:01<27:01, 291kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.1M/498M [01:01<27:16, 288kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.1M/498M [01:01<24:26, 322kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.1M/498M [01:01<22:10, 354kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.2M/498M [01:01<22:11, 354kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.2M/498M [01:01<21:11, 371kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.3M/498M [01:01<20:45, 379kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.3M/498M [01:01<20:26, 384kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.4M/498M [01:02<19:37, 400kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.4M/498M [01:02<20:05, 391kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.5M/498M [01:02<20:00, 393kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.5M/498M [01:02<19:48, 396kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.6M/498M [01:02<21:05, 372kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.6M/498M [01:02<21:12, 370kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.6M/498M [01:02<21:56, 358kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.7M/498M [01:02<21:37, 363kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.7M/498M [01:03<21:56, 358kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.8M/498M [01:03<21:12, 370kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.8M/498M [01:03<21:23, 367kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.9M/498M [01:03<20:58, 374kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 26.9M/498M [01:03<18:09, 432kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 27.0M/498M [01:03<18:05, 434kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 27.1M/498M [01:03<16:27, 477kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 27.1M/498M [01:03<15:24, 509kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 27.2M/498M [01:03<13:41, 573kiB/s]
# model.ckpt.data-00000-of-00001:   5%|▌         | 27.3M/498M [01:04<13:02, 601kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.4M/498M [01:04<12:19, 636kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.4M/498M [01:04<13:22, 586kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.5M/498M [01:04<14:57, 524kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.6M/498M [01:04<18:59, 413kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.6M/498M [01:04<19:05, 410kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.6M/498M [01:04<19:22, 405kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.7M/498M [01:05<21:20, 367kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.7M/498M [01:05<23:28, 334kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.8M/498M [01:05<22:39, 346kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.8M/498M [01:05<21:09, 370kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.9M/498M [01:05<21:32, 364kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 27.9M/498M [01:05<21:51, 358kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.0M/498M [01:05<22:27, 349kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.0M/498M [01:06<23:02, 340kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.0M/498M [01:06<24:14, 323kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.1M/498M [01:06<22:53, 342kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.1M/498M [01:06<22:54, 342kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.1M/498M [01:06<24:08, 324kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.2M/498M [01:06<22:02, 355kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.2M/498M [01:06<20:41, 378kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.3M/498M [01:06<19:46, 396kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.3M/498M [01:06<19:12, 407kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.4M/498M [01:07<19:26, 402kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.4M/498M [01:07<18:55, 413kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.5M/498M [01:07<18:36, 420kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.5M/498M [01:07<18:21, 426kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.6M/498M [01:07<16:32, 472kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.7M/498M [01:07<17:24, 449kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.7M/498M [01:07<15:59, 489kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.8M/498M [01:07<17:36, 444kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.8M/498M [01:08<18:01, 434kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.9M/498M [01:08<18:31, 422kiB/s]
# model.ckpt.data-00000-of-00001:   6%|▌         | 28.9M/498M [01:08<21:24, 365kiB/s]
# ...
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:20, 524kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:21, 510kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:22, 492kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:26, 412kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:26, 405kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:26, 405kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:27, 387kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:04<00:27, 382kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:29, 361kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:28, 368kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:27, 388kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:25, 402kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:24, 415kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:24, 422kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 487M/498M [19:05<00:24, 414kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:05<00:27, 378kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:27, 371kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:26, 390kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:26, 380kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:27, 360kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:32, 312kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:31, 314kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:28, 346kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:06<00:27, 362kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:25, 384kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:24, 399kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:23, 421kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:20, 470kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:17, 549kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:15, 602kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:14, 639kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 488M/498M [19:07<00:14, 667kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:07<00:12, 728kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:11, 818kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:11, 770kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:12, 724kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:14, 600kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:15, 582kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:15, 574kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:16, 541kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:08<00:15, 548kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:15, 539kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:16, 527kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:16, 511kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:15, 529kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:14, 561kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 489M/498M [19:09<00:13, 611kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:09<00:12, 673kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:09<00:11, 706kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:09<00:11, 694kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:13, 605kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:13, 590kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:13, 582kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:15, 510kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:15, 487kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:16, 476kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:16, 466kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:10<00:16, 453kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:11<00:18, 399kiB/s]
# model.ckpt.data-00000-of-00001:  98%|█████████▊| 490M/498M [19:11<00:19, 390kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 490M/498M [19:11<00:19, 380kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 490M/498M [19:11<00:19, 372kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 490M/498M [19:11<00:22, 329kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 490M/498M [19:11<00:20, 359kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:11<00:19, 380kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:11<00:19, 371kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:17, 417kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:16, 422kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:14, 471kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:15, 456kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:12, 536kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:12, 551kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:13, 507kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:13, 495kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:12<00:14, 449kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:15, 438kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:14, 457kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:13, 494kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:12, 520kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:10, 580kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 491M/498M [19:13<00:11, 567kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▊| 492M/498M [19:13<00:10, 572kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:13<00:12, 506kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:13, 453kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:14, 432kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:14, 423kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:15, 387kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:13, 428kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:14, 419kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:14, 409kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:14<00:14, 399kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:14, 398kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:14, 401kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:13, 412kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:13, 402kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:13, 412kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:12, 438kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:11, 479kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:10, 510kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 492M/498M [19:15<00:09, 573kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:08, 619kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:07, 693kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:06, 746kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:07, 676kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:07, 631kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:07, 618kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:07, 599kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:16<00:08, 544kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:17<00:08, 535kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:17<00:07, 575kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:17<00:07, 592kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:17<00:06, 632kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 493M/498M [19:17<00:07, 609kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:17<00:06, 642kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:17<00:06, 641kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:17<00:06, 630kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:06, 620kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:06, 600kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:06, 572kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:07, 527kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:07, 497kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:07, 473kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:07, 461kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:18<00:08, 437kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:09, 388kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:09, 379kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:09, 371kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:10, 339kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:09, 356kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 494M/498M [19:19<00:09, 355kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:19<00:09, 345kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:19<00:08, 361kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:08, 381kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:07, 397kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:07, 407kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:06, 457kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:05, 493kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:05, 522kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:04, 578kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:20<00:04, 564kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:21<00:04, 546kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:21<00:05, 473kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:21<00:05, 463kiB/s]
# model.ckpt.data-00000-of-00001:  99%|█████████▉| 495M/498M [19:21<00:06, 415kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 495M/498M [19:21<00:06, 406kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 495M/498M [19:21<00:06, 373kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 495M/498M [19:21<00:06, 363kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 495M/498M [19:21<00:06, 358kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 495M/498M [19:22<00:06, 371kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 389kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 374kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 373kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 369kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 366kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:05, 385kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:22<00:04, 400kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:04, 411kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:04, 429kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:03, 475kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:03, 507kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:03, 530kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:02, 590kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:02, 612kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:23<00:02, 574kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:24<00:02, 458kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 496M/498M [19:24<00:02, 441kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:02, 434kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:02, 425kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:02, 405kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:02, 452kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:02, 487kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:24<00:01, 515kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:01, 575kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:01, 621kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:01, 651kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:00, 717kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:00, 765kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:00, 732kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:00, 728kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 497M/498M [19:25<00:00, 729kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 498M/498M [19:25<00:00, 730kiB/s]
# model.ckpt.data-00000-of-00001: 100%|█████████▉| 498M/498M [19:26<00:00, 773kiB/s]
# model.ckpt.data-00000-of-00001: 100%|██████████| 498M/498M [19:26<00:00, 427kiB/s]
#
# model.ckpt.index:   0%|          | 0.00/5.21k [00:00<?, ?iB/s]
# model.ckpt.index: 100%|██████████| 5.21k/5.21k [00:00<00:00, 207kiB/s]
#
# model.ckpt.meta:   0%|          | 0.00/471k [00:00<?, ?iB/s]
# model.ckpt.meta:   7%|▋         | 32.8k/471k [00:00<00:02, 205kiB/s]
# model.ckpt.meta:  21%|██        | 98.3k/471k [00:00<00:01, 327kiB/s]
# model.ckpt.meta:  49%|████▊     | 229k/471k [00:00<00:00, 557kiB/s]
# model.ckpt.meta: 100%|██████████| 471k/471k [00:00<00:00, 895kiB/s]
#
# vocab.bpe:   0%|          | 0.00/456k [00:00<?, ?iB/s]
# vocab.bpe:   7%|▋         | 32.8k/456k [00:00<00:02, 210kiB/s]
# vocab.bpe:  25%|██▌       | 115k/456k [00:00<00:00, 394kiB/s]
# vocab.bpe:  57%|█████▋    | 262k/456k [00:00<00:00, 644kiB/s]
# vocab.bpe: 100%|██████████| 456k/456k [00:00<00:00, 968kiB/s]

# %% [markdown]
# # EXERCISE 6.2 FINETUNING THE WHOLE MODEL
# Instead of finetuning just the final transformer block, finetune the entire model and
# assess the impact on predictive performance.

# %%
max_length = 120

# %%
train_dataset = SpamDataset(
    csv_file="train.csv",
    max_length=max_length,
    tokenizer=tokenizer
)

val_dataset = SpamDataset(
    csv_file="validation.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)
test_dataset = SpamDataset(
    csv_file="test.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)

print(train_dataset.max_length)
# Out:
# 120

# %%
from torch.utils.data import DataLoader

num_workers = 0
batch_size = 8

torch.manual_seed(123)

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    drop_last=True,
)
val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)

# %%
from gpt_download import download_and_load_gpt2
from previous_chapters import GPTModel, load_weights_into_gpt

# 下载预训练模型权重
model_size = CHOOSE_MODEL.split(" ")[-1].lstrip("(").rstrip(")")
settings, params = download_and_load_gpt2(model_size=model_size, models_dir="gpt2")
model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.to(device)
model.eval()
# Out:
# File already exists and is up-to-date: gpt2\124M\checkpoint
# File already exists and is up-to-date: gpt2\124M\encoder.json
# File already exists and is up-to-date: gpt2\124M\hparams.json
# File already exists and is up-to-date: gpt2\124M\model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2\124M\model.ckpt.index
# File already exists and is up-to-date: gpt2\124M\model.ckpt.meta
# File already exists and is up-to-date: gpt2\124M\vocab.bpe
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNorm()
#   (out_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# 冻结参数
for param in model.parameters():
    param.requires_grad = True

# %%
# 训练模型
import time

start_time = time.time()

torch.manual_seed(123)

optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.1)

num_epochs = 5
train_losses, val_losses, train_accs, val_accs, examples_seen = train_classifier_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=50, eval_iter=5,
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000) Train loss 3.917, Val loss 4.082
# Ep 1 (Step 000050) Train loss 0.544, Val loss 0.469
# Ep 1 (Step 000100) Train loss 0.128, Val loss 0.204
# Training accuracy: 95.00% | Validation accuracy: 87.50%
# Ep 2 (Step 000150) Train loss 0.216, Val loss 0.065
# Ep 2 (Step 000200) Train loss 0.092, Val loss 0.052
# Ep 2 (Step 000250) Train loss 0.039, Val loss 0.036
# Training accuracy: 92.50% | Validation accuracy: 100.00%
# Ep 3 (Step 000300) Train loss 0.030, Val loss 0.157
# Ep 3 (Step 000350) Train loss 0.005, Val loss 0.037
# Training accuracy: 100.00% | Validation accuracy: 97.50%
# Ep 4 (Step 000400) Train loss 0.005, Val loss 0.083
# Ep 4 (Step 000450) Train loss 0.003, Val loss 0.014
# Ep 4 (Step 000500) Train loss 0.001, Val loss 0.029
# Training accuracy: 100.00% | Validation accuracy: 95.00%
# Ep 5 (Step 000550) Train loss 0.000, Val loss 0.132
# Ep 5 (Step 000600) Train loss 0.000, Val loss 0.158
# Training accuracy: 100.00% | Validation accuracy: 97.50%
# Training completed in 4.93 minutes.

# %%
train_accuracy = calc_accuracy_loader(train_loader, model, device)
val_accuracy = calc_accuracy_loader(val_loader, model, device)
test_accuracy = calc_accuracy_loader(test_loader, model, device)

print(f"Training accuracy: {train_accuracy*100:.2f}%")
print(f"Validation accuracy: {val_accuracy*100:.2f}%")
print(f"Test accuracy: {test_accuracy*100:.2f}%")
# Out:
# Training accuracy: 100.00%
# Validation accuracy: 97.32%
# Test accuracy: 96.67%

# %%
! cd ..\..\ch06\02_bonus_additional-experiments && python additional_experiments.py --trainable_layers all
# Out:
# File already exists and is up-to-date: gpt2\124M\checkpoint
# File already exists and is up-to-date: gpt2\124M\encoder.json
# File already exists and is up-to-date: gpt2\124M\hparams.json
# File already exists and is up-to-date: gpt2\124M\model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2\124M\model.ckpt.index
# File already exists and is up-to-date: gpt2\124M\model.ckpt.meta
# File already exists and is up-to-date: gpt2\124M\vocab.bpe
# Ep 1 (Step 000000): Train loss 2.230, Val loss 2.499
# Ep 1 (Step 000050): Train loss 0.247, Val loss 0.136
# Ep 1 (Step 000100): Train loss 0.188, Val loss 0.194
# Training accuracy: 97.50% | Validation accuracy: 95.00%
# Ep 2 (Step 000150): Train loss 0.454, Val loss 0.117
# Ep 2 (Step 000200): Train loss 0.165, Val loss 0.126
# Ep 2 (Step 000250): Train loss 0.101, Val loss 0.087
# Training accuracy: 100.00% | Validation accuracy: 95.00%
# Ep 3 (Step 000300): Train loss 0.065, Val loss 0.113
# Ep 3 (Step 000350): Train loss 0.031, Val loss 0.147
# Training accuracy: 100.00% | Validation accuracy: 97.50%
# Ep 4 (Step 000400): Train loss 0.006, Val loss 0.112
# Ep 4 (Step 000450): Train loss 0.004, Val loss 0.146
# Ep 4 (Step 000500): Train loss 0.002, Val loss 0.138
# Training accuracy: 100.00% | Validation accuracy: 95.00%
# Ep 5 (Step 000550): Train loss 0.000, Val loss 0.196
# Ep 5 (Step 000600): Train loss 0.003, Val loss 0.136
# Training accuracy: 100.00% | Validation accuracy: 97.50%
# Training completed in 3.70 minutes.
# Training accuracy: 99.42%
# Validation accuracy: 95.97%
# Test accuracy: 96.67%
# 2025-04-27 21:27:38.855786: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 21:27:39.895841: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# # EXERCISE 6.3 FINETUNING THE FIRST VERSUS LAST TOKEN
# Rather than finetuning the last output token, try finetuning the first output token and
# observe the changes in predictive performance when finetuning the model in later
# sections.

# %%
max_length = 120

# %%
train_dataset = SpamDataset(
    csv_file="train.csv",
    max_length=max_length,
    tokenizer=tokenizer
)

val_dataset = SpamDataset(
    csv_file="validation.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)
test_dataset = SpamDataset(
    csv_file="test.csv",
    max_length=train_dataset.max_length,
    tokenizer=tokenizer
)

print(train_dataset.max_length)
# Out:
# 120

# %%
from torch.utils.data import DataLoader

num_workers = 0
batch_size = 8

torch.manual_seed(123)

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=num_workers,
    drop_last=True,
)
val_loader = DataLoader(
    dataset=val_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    num_workers=num_workers,
    drop_last=False,
)

# %%
# 计算分类准备率
def calc_accuracy_loader(data_loader, model, device, num_batches=None):
    model.eval()
    correct_predictions, num_examples = 0, 0
    if num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))

    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            # 将数据移到指定设备
            input_batch, target_batch = input_batch.to(device), target_batch.to(device)
            # 模型预估
            with torch.no_grad():
                logits = model(input_batch)[:, 0, :]
            # 获取分类结果
            predicted_labels = torch.argmax(logits, dim=-1)
            # 统计总样本量、分类正确样本量
            num_examples += predicted_labels.shape[0]
            correct_predictions += (predicted_labels == target_batch).sum().item()
        else:
            break
    return correct_predictions / num_examples

# %%
# 定义batch训练损失
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    # 只关注最后一个输出
    logits = model(input_batch)[:, 0, :]
    # 交叉熵损失
    loss = torch.nn.functional.cross_entropy(logits, target_batch)
    return loss

# %%
# 定义loader训练损失
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        for i, (input_batch, target_batch) in enumerate(data_loader):
            if i < num_batches:
                loss = calc_loss_batch(input_batch, target_batch, model, device)
                total_loss += loss.item()
            else:
                break
    return total_loss / num_batches

# %%
from gpt_download import download_and_load_gpt2
from previous_chapters import GPTModel, load_weights_into_gpt

# 下载预训练模型权重
model_size = CHOOSE_MODEL.split(" ")[-1].lstrip("(").rstrip(")")
settings, params = download_and_load_gpt2(model_size=model_size, models_dir="gpt2")
model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.to(device)
model.eval()
# Out:
# File already exists and is up-to-date: gpt2\124M\checkpoint
# File already exists and is up-to-date: gpt2\124M\encoder.json
# File already exists and is up-to-date: gpt2\124M\hparams.json
# File already exists and is up-to-date: gpt2\124M\model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2\124M\model.ckpt.index
# File already exists and is up-to-date: gpt2\124M\model.ckpt.meta
# File already exists and is up-to-date: gpt2\124M\vocab.bpe
# GPTModel(
#   (tok_emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (drop_emb): Dropout(p=0.0, inplace=False)
#   (trf_blocks): Sequential(
#     (0): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (1): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (2): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (3): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (4): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (5): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (6): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (7): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (8): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (9): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (10): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#     (11): TransformerBlock(
#       (att): MultiHeadAttention(
#         (W_query): Linear(in_features=768, out_features=768, bias=True)
#         (W_key): Linear(in_features=768, out_features=768, bias=True)
#         (W_value): Linear(in_features=768, out_features=768, bias=True)
#         (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (ff): FeedForward(
#         (layers): Sequential(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU()
#           (2): Linear(in_features=3072, out_features=768, bias=True)
#         )
#       )
#       (norm1): LayerNorm()
#       (norm2): LayerNorm()
#       (drop_resid): Dropout(p=0.0, inplace=False)
#     )
#   )
#   (final_norm): LayerNorm()
#   (out_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# 冻结参数
for param in model.parameters():
    param.requires_grad = False

# %%
# 除了输出层外，令trf的最后一个模块和final_norm的参数可训练
for param in model.trf_blocks[-1].parameters():
    param.requires_grad = True

for param in model.final_norm.parameters():
    param.requires_grad = True

# %%
# 训练模型
import time

start_time = time.time()

torch.manual_seed(123)

optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5, weight_decay=0.1)

num_epochs = 5
train_losses, val_losses, train_accs, val_accs, examples_seen = train_classifier_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=50, eval_iter=5,
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000) Train loss 5.973, Val loss 5.965
# Ep 1 (Step 000050) Train loss 0.781, Val loss 0.870
# Ep 1 (Step 000100) Train loss 0.616, Val loss 0.757
# Training accuracy: 72.50% | Validation accuracy: 50.00%
# Ep 2 (Step 000150) Train loss 0.636, Val loss 0.748
# Ep 2 (Step 000200) Train loss 0.564, Val loss 0.681
# Ep 2 (Step 000250) Train loss 0.560, Val loss 0.729
# Training accuracy: 72.50% | Validation accuracy: 60.00%
# Ep 3 (Step 000300) Train loss 0.557, Val loss 0.656
# Ep 3 (Step 000350) Train loss 0.492, Val loss 0.687
# Training accuracy: 75.00% | Validation accuracy: 52.50%
# Ep 4 (Step 000400) Train loss 0.492, Val loss 0.634
# Ep 4 (Step 000450) Train loss 0.457, Val loss 0.639
# Ep 4 (Step 000500) Train loss 0.458, Val loss 0.642
# Training accuracy: 75.00% | Validation accuracy: 67.50%
# Ep 5 (Step 000550) Train loss 0.516, Val loss 0.624
# Ep 5 (Step 000600) Train loss 0.388, Val loss 0.609
# Training accuracy: 77.50% | Validation accuracy: 55.00%
# Training completed in 1.97 minutes.

# %%
train_accuracy = calc_accuracy_loader(train_loader, model, device)
val_accuracy = calc_accuracy_loader(val_loader, model, device)
test_accuracy = calc_accuracy_loader(test_loader, model, device)

print(f"Training accuracy: {train_accuracy*100:.2f}%")
print(f"Validation accuracy: {val_accuracy*100:.2f}%")
print(f"Test accuracy: {test_accuracy*100:.2f}%")
# Out:
# Training accuracy: 76.83%
# Validation accuracy: 73.15%
# Test accuracy: 73.33%

# %%
! cd ..\..\ch06\02_bonus_additional-experiments && python additional_experiments.py --trainable_token first
# Out:
# File already exists and is up-to-date: gpt2\124M\checkpoint
# File already exists and is up-to-date: gpt2\124M\encoder.json
# File already exists and is up-to-date: gpt2\124M\hparams.json
# File already exists and is up-to-date: gpt2\124M\model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2\124M\model.ckpt.index
# File already exists and is up-to-date: gpt2\124M\model.ckpt.meta
# File already exists and is up-to-date: gpt2\124M\vocab.bpe
# Ep 1 (Step 000000): Train loss 1.592, Val loss 1.446
# Ep 1 (Step 000050): Train loss 0.719, Val loss 0.709
# Ep 1 (Step 000100): Train loss 0.621, Val loss 0.690
# Training accuracy: 65.00% | Validation accuracy: 57.50%
# Ep 2 (Step 000150): Train loss 0.663, Val loss 0.678
# Ep 2 (Step 000200): Train loss 0.632, Val loss 0.650
# Ep 2 (Step 000250): Train loss 0.581, Val loss 0.643
# Training accuracy: 85.00% | Validation accuracy: 67.50%
# Ep 3 (Step 000300): Train loss 0.515, Val loss 0.615
# Ep 3 (Step 000350): Train loss 0.476, Val loss 0.609
# Training accuracy: 75.00% | Validation accuracy: 67.50%
# Ep 4 (Step 000400): Train loss 0.628, Val loss 0.590
# Ep 4 (Step 000450): Train loss 0.484, Val loss 0.573
# Ep 4 (Step 000500): Train loss 0.450, Val loss 0.594
# Training accuracy: 72.50% | Validation accuracy: 70.00%
# Ep 5 (Step 000550): Train loss 0.403, Val loss 0.559
# Ep 5 (Step 000600): Train loss 0.402, Val loss 0.565
# Training accuracy: 82.50% | Validation accuracy: 70.00%
# Training completed in 2.85 minutes.
# Training accuracy: 78.46%
# Validation accuracy: 80.54%
# Test accuracy: 75.00%
# 2025-04-27 21:32:02.549704: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 21:32:03.513091: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
